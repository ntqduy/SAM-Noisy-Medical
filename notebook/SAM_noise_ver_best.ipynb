# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # 0. Token

# %%
# Token: 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

# %%
import getpass, os
os.environ["GITHUB_TOKEN"] = getpass.getpass("GitHub PAT: ")
os.environ["GITHUB_USER"]  = "ntqduy"  # username của tài khoản đã tạo token
# Out:
# GitHub PAT: ··········

# %%
# !git clone "https://x-access-token:${GITHUB_TOKEN}@github.com/ntqduy/SAM-Noisy-Medical.git"
# Out:
# Cloning into 'SAM-Noisy-Medical'...
# remote: Enumerating objects: 306, done.
# remote: Counting objects: 100% (306/306), done.
# remote: Compressing objects: 100% (204/204), done.
# remote: Total 306 (delta 133), reused 250 (delta 77), pack-reused 0 (from 0)
# Receiving objects: 100% (306/306), 329.05 KiB | 4.91 MiB/s, done.
# Resolving deltas: 100% (133/133), done.

# %% [markdown]
# # Dowload Data and weight

# %% [markdown]
# Weight

# %%
# !gdown 1OB4opCiORm0MUvFF2KSx99barSioN8rS
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1OB4opCiORm0MUvFF2KSx99barSioN8rS
# From (redirected): https://drive.google.com/uc?id=1OB4opCiORm0MUvFF2KSx99barSioN8rS&confirm=t&uuid=373e3a51-ee1f-452d-8d5f-e79a8922880a
# To: /content/sam_vit_b_01ec64.pth
# 100% 375M/375M [00:02<00:00, 133MB/s]

# %%
# !gdown 1x7XLrJ0GgyFRlQtIj26zb_rfpj15b3aZ
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1x7XLrJ0GgyFRlQtIj26zb_rfpj15b3aZ
# From (redirected): https://drive.google.com/uc?id=1x7XLrJ0GgyFRlQtIj26zb_rfpj15b3aZ&confirm=t&uuid=29dee2a5-1948-454e-8451-e4f9a813b87b
# To: /content/sam_vit_l_0b3195.pth
# 100% 1.25G/1.25G [00:13<00:00, 94.4MB/s]

# %% [markdown]
# Data

# %%
# !gdown 1lx8Lfzw3eWKURj1npCAnkyTf2im8sDzg
# !unzip -q Montgomery.zip -d Montgomery
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1lx8Lfzw3eWKURj1npCAnkyTf2im8sDzg
# From (redirected): https://drive.google.com/uc?id=1lx8Lfzw3eWKURj1npCAnkyTf2im8sDzg&confirm=t&uuid=161868fe-80e1-4f89-a3b1-48a34abdf35f
# To: /content/Montgomery.zip
# 100% 33.1M/33.1M [00:00<00:00, 116MB/s]

# %% [markdown]
# # 2. Move weight

# %%
# !cp "/content/sam_vit_b_01ec64.pth"  "/content/SAM-Noisy-Medical/weights"

# %%
# !cp "/content/sam_vit_l_0b3195.pth"  "/content/SAM-Noisy-Medical/weights"

# %% [markdown]
# # 3. Run Model

# %%
# %cd SAM-Noisy-Medical
# Out:
# /content/SAM-Noisy-Medical

# %% [markdown]
# ## 3.1 DowLoad SAM1

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# ...
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-qnjax5_w
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-qnjax5_w
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for segment_anything: filename=segment_anything-1.0-py3-none-any.whl size=36592 sha256=43f53b1cb0024e9119b0a3a9f725023215c399a667042cb2fad1d1cde8bd8a86
#   Stored in directory: /tmp/pip-ephem-wheel-cache-pm3q_j0q/wheels/29/82/ff/04e2be9805a1cb48bec0b85b5a6da6b63f647645750a0e42d4
# Successfully built segment_anything
# ...

# %% [markdown]
# ## 3.1.1 Install SAM2

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything-2.git

# %% [markdown]
# ## 3.2 DowLoad Lib

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 27.6 MB/s eta 0:00:00
# ...

# %%
# !pip install torch torchvision --index-url https://download.pytorch.org/whl/cu118

# %% [markdown]
# # 3.4 Run

# %%
# !python main.py --config configs/phase1.yaml --max_noise gaussian,poisson --use_cache

# %%
# !python main.py --config configs/phase1.yaml --max_noise gaussian

# %%
# !python main.py --config configs/phase1.yaml --debug --max_samples 20
# Out:
# montgomery | SAM/sam_b | prompt_bbox | P0:clean:L0: 100% 20/20 [00:06<00:00,  3.12it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:gaussian:L1: 100% 20/20 [00:05<00:00,  3.98it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:gaussian:L2: 100% 20/20 [00:05<00:00,  3.80it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:gaussian:L3: 100% 20/20 [00:05<00:00,  3.80it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:gaussian:L4: 100% 20/20 [00:05<00:00,  3.81it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:poisson:L1: 100% 20/20 [00:05<00:00,  3.76it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:poisson:L2: 100% 20/20 [00:05<00:00,  3.65it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:poisson:L3: 100% 20/20 [00:05<00:00,  3.70it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:poisson:L4: 100% 20/20 [00:05<00:00,  3.54it/s]
# montgomery | SAM/sam_b | prompt_bbox | P1:salt_pepper:L1: 100% 20/20 [00:05<00:00,  3.97it/s]
# ...

# %%
# !python main.py --config configs/phase1.yaml

# %%
# !git pull "https://x-access-token:${GITHUB_TOKEN}@github.com/ntqduy/SAM-Noisy-Medical.git"
# Out:
# From https://github.com/ntqduy/SAM-Noisy-Medical
#  * branch            HEAD       -> FETCH_HEAD
# Updating 1454b73..524026b
# Fast-forward
#  .../meta/config_snapshot.json                      |   9 +-
#  reports/__pycache__/pdf_builder.cpython-310.pyc    | Bin 28180 -> 31725 bytes
#  reports/pdf_builder.py                             | 161 ++++++++---
#  runner/__pycache__/experiment.cpython-310.pyc      | Bin 15600 -> 16527 bytes
#  runner/experiment.py                               |  47 +++-
#  viz/__pycache__/grids.cpython-310.pyc              | Bin 26219 -> 32068 bytes
#  viz/__pycache__/plots.cpython-310.pyc              | Bin 27658 -> 32301 bytes
#  viz/grids.py                                       | 298 ++++++++++++++++++++-
#  viz/plots.py                                       | 221 +++++++++++++++
#  9 files changed, 698 insertions(+), 38 deletions(-)

# %%
# !python main.py --config configs/phase1.yaml --only_report
# Out:
# [INFO] Report-only mode: regenerating report from existing results.csv
#
# [INFO] Generating plots...
# [INFO] Generated 364 plots.
# [INFO] Generated 10 noise visualization images.
# [INFO] Generated 2 comprehensive comparison images.
# [INFO] Generated 6 noise type gallery images.
# INFO: Available modes: ['prompt_bbox', 'automatic']
# INFO: Exporting 8 failure cases for mode: prompt_bbox
# INFO: Exported 8 failure case visualizations
# INFO: Exporting 8 failure cases for mode: automatic
# INFO: Exported 8 failure case visualizations
# INFO: Exporting 8 combined failure cases
# INFO: Exported 8 failure case visualizations
# INFO: Created failure summary: outputs/phase1_xray_controlled/failure_cases/failure_summary.md
# INFO: Total exported: 24 failure case visualizations
#
# [DONE]
# - results: outputs/phase1_xray_controlled/results.csv
# - aggregate: outputs/phase1_xray_controlled/aggregate.csv
# - stability: outputs/phase1_xray_controlled/stability.csv
# ...

# %%
# !rsync -avh --progress "/content/SAM-Noisy-Medical/outputs" "/content/drive/MyDrive/outputs/"
# Out:
# Streaming output truncated to the last 5000 lines.
#           1.97K 100%    2.63kB/s    0:00:00 (xfr#10295, ir-chk=1002/12050)
# outputs/phase1_xray_controlled/pred_masks/montgomery/SAM/sam_l/automatic/P2a/bias_field/L3/seed42/MCUCXR_0026_0.png
#           2.03K 100%    2.71kB/s    0:00:00 (xfr#10296, ir-chk=1001/12050)
# outputs/phase1_xray_controlled/pred_masks/montgomery/SAM/sam_l/automatic/P2a/bias_field/L3/seed42/MCUCXR_0027_0.png
#             899 100%    1.20kB/s    0:00:00 (xfr#10297, ir-chk=1000/12050)
# outputs/phase1_xray_controlled/pred_masks/montgomery/SAM/sam_l/automatic/P2a/bias_field/L4/
# outputs/phase1_xray_controlled/pred_masks/montgomery/SAM/sam_l/automatic/P2a/bias_field/L4/seed42/
# outputs/phase1_xray_controlled/pred_masks/montgomery/SAM/sam_l/automatic/P2a/bias_field/L4/seed42/MCUCXR_0001_0.png
#             994 100%    1.33kB/s    0:00:00 (xfr#10298, ir-chk=1020/12072)
# ...
